# %%
import finalmodule as fm
# Out:
# <div id="glowscript" class="glowscript"></div>

# %%
def main():
    
    omegay,omegaz,v0y,theta,v0 = fm.ask()
    xs,ys,zs,v0 = fm.runge(0.01,v0,v0y,omegay,omegaz,theta)   #time step of 0.01 seconds
    fm.makefield(xs,ys,zs,v0)
    xf,yf,zf = fm.plot(xs,ys,zs)
    fm.bigplot(xf,yf,zf)
    
if __name__=="__main__":
    main()
# Out:
# FB, CB, or SL SL
# Velocity of pitch (mph) 90
# <div id="glowscript" class="glowscript"></div>
